# %% [markdown]
# # 01 — Data Exploration
#
# Exploratory analysis of the 30-year daily close dataset (Universe A).
#
# **Outputs:** figures saved to `results/figures/eda/`

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

from src.config import Config
from src.data_loader import load_market_data, compute_price_returns

cfg = Config.from_yaml(ROOT / 'configs/config.yaml')
bundle = load_market_data(cfg)
print(bundle.metadata)
bundle.investable_prices.head()

# %%
# Generate all EDA figures
# %run ../scripts/run_eda.py

# %%
from IPython.display import Image, display
eda_dir = ROOT / 'results/figures/eda'
for fig in sorted(eda_dir.glob('*.png')):
    print(fig.name)
    display(Image(filename=str(fig)))
