# %% [markdown]
# # 02 — Evaluation Plots
#
# Visualize backtest results, walk-forward metrics, and ablation studies.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

import pandas as pd
from IPython.display import Image, display

test = pd.read_csv(ROOT / 'results/tables/headline_test_metrics.csv', index_col=0)
test

# %%
# %run ../scripts/run_eval_plots.py

# %%
eval_dir = ROOT / 'results/figures/eval'
for fig in sorted(eval_dir.glob('*.png')):
    print(fig.name)
    display(Image(filename=str(fig)))
